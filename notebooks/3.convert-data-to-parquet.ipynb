# %%
import pandas as pd

# %%
data_path = 'data/frases-musicas-final-filled.csv'
df = pd.read_csv(data_path)
df
# Out:
#          music_id  music_frase_id  \
# 0               1               1
# 1               1               2
# 2               1               3
# 3               1               4
# 4               1               5
# ...           ...             ...
# 2685690    146609             480
# 2685691    146611               4
# 2685692    146611              10
# 2685693    146611              14
# 2685694    146611              18
#
#                                                      frase  frase_id  \
# 0           Carolina é uma menina bem difícil de esquecer.         1
# 1                       Andar bonito e um brilho no olhar.         2
# 2         Tem um jeito adolescente que me faz enlouquecer.         3
# 3                   E um molejo que eu não vou te enganar.         4
# 4                 Maravilha feminina, meu docinho de pavê.         5
# ...                                                    ...       ...
# ...

# %%
df.columns
# Out:
# Index(['music_id', 'music_frase_id', 'frase', 'frase_id', 'tem_padrao',
#        'padrao_encontrado'],
#       dtype='object')

# %%
df.to_parquet('data/frases-musicas-final-filled.parquet', index=False)

# %%
df_selected = df[['frase', 'frase_id']]
df_selected.to_parquet('data/frases-musicas-final-filled-selected.parquet', index=False)
