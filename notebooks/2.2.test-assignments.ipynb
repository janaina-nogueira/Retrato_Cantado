# %%
import pandas as pd

# %%
path = 'data/assignments.csv'
df = pd.read_csv(path)
df
# Out:
#       annotator_id  frase_id
# 0           user01   1905201
# 1           user01   4278896
# 2           user01   3090531
# 3           user01   2056355
# 4           user01   1971942
# ...            ...       ...
# 69995       user35   2304718
# 69996       user35   1864909
# 69997       user35   4211722
# 69998       user35    994935
# 69999       user35   2112888
#
# [70000 rows x 2 columns]

# %%
# verifica como está a distribuição dos valores de 'frase_id' na coluna 'annotator_id', isso é, com quantos anotadores cada frase foi anotada
df['frase_id'].value_counts().plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
distribuicao = df['frase_id'].value_counts()
distribuicao.describe()
# Out:
# count    18831.000000
# mean         3.717275
# std          2.348102
# min          2.000000
# 25%          3.000000
# 50%          4.000000
# 75%          4.000000
# max         35.000000
# Name: count, dtype: float64

# %%
df_shuffled = df.sample(frac=1).sort_values(by='annotator_id').reset_index(drop=True)

# %%
df_shuffled
# Out:
#       annotator_id  frase_id
# 0           user01    394315
# 1           user01    650570
# 2           user01    119894
# 3           user01    422159
# 4           user01   2863507
# ...            ...       ...
# 69995       user35   2324000
# 69996       user35   2227938
# 69997       user35   1217206
# 69998       user35    376277
# 69999       user35    668613
#
# [70000 rows x 2 columns]

# %%
df_shuffled.to_csv('data/assignments-shuffled.csv', index=False)
